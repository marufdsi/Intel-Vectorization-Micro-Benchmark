# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from copy import deepcopy as copy
import matplotlib.backends.backend_pdf
import scipy as sp
import scipy.stats as stats
import math
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'
# plotly.tools.set_credentials_file(username='mhossa10', api_key='CSWpOV3xHUVRzimjfHSB')

# %%
init_log_file = pd.read_csv('init_log_file.csv')
init_log_file['Implicit Performance'] = init_log_file['Degree']/init_log_file['Implicit TIme']
init_log_file['Intrinsic Performance'] = init_log_file['Degree']/init_log_file['Intrinsic Time']
ax=init_log_file.plot(kind='bar', x='Degree', y=['Implicit Performance','Intrinsic Performance'], logy=True, figsize=(15,7))
ax.set_ylabel('Performance(Degree/Second)')
# Out:
# Text(0,0.5,'Performance(Degree/Second)')
